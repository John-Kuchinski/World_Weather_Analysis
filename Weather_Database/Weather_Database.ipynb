# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import Dependencies
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from config import wx_apiKey
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates[1])
# Out:
# (57.18719563034924, -14.478410131506365)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []


# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    c = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mt/85yyqb616k510zt4395vhhnh0000gn/T/ipykernel_22962/2344625587.py in <module>
#       9
#      10     # If the city is unique, then add it to a our cities list
# ---> 11     if city not in cities:
#      12         cities.append(city)
#      13
#
# NameError: name 'city' is not defined

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import wx_apiKey

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wx_apiKey

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
       
    # Group cities in sets of 50 for logging purposes/ rate limiting of the API call.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_tempMax = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        
        
            
        # Append the city information into the city_data list
        city_data.append({"City": city_name,
                          "Latitude": city_lat,
                          "Longitude": city_lng, 
                          "Max Temp": city_tempMax, 
                          "Humidity": city_humidity, 
                          "Cloudiness": city_cloudiness, 
                          "Wind Speed": city_wind, 
                          "Country": city_country, 
                          "Weather Description": city_weatherDescription 
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katangli
# Processing Record 2 of Set 1 | denpasar
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | mamlyutka
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | el alto
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | westerland
# Processing Record 18 of Set 1 | port hedland
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | fort nelson
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | itoman
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | severo-yeniseyskiy
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | kieta
# Processing Record 34 of Set 1 | marystown
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | humaita
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | aulnoye-aymeries
# Processing Record 44 of Set 1 | anaconda
# Processing Record 45 of Set 1 | bondo
# Processing Record 46 of Set 1 | atasu
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | mount gambier
# Processing Record 49 of Set 1 | lagoa
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 2 | pochutla
# Processing Record 3 of Set 2 | whitianga
# Processing Record 4 of Set 2 | cabra
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | batsfjord
# Processing Record 7 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 2 | ballina
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | chulym
# Processing Record 11 of Set 2 | vila franca do campo
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | kirovskiy
# Processing Record 15 of Set 2 | olafsvik
# Processing Record 16 of Set 2 | tuburan
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | sangar
# Processing Record 20 of Set 2 | dvinskoy
# Processing Record 21 of Set 2 | poum
# Processing Record 22 of Set 2 | tutoia
# Processing Record 23 of Set 2 | hobyo
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | san andres
# Processing Record 27 of Set 2 | dubbo
# Processing Record 28 of Set 2 | svetlogorsk
# Processing Record 29 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 2 | umm lajj
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | porbandar
# Processing Record 33 of Set 2 | jacareacanga
# Processing Record 34 of Set 2 | polyarnyy
# Processing Record 35 of Set 2 | shimoda
# Processing Record 36 of Set 2 | mehamn
# Processing Record 37 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 2 | kysyl-syr
# Processing Record 39 of Set 2 | sinjah
# City not found. Skipping...
# Processing Record 40 of Set 2 | coos bay
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | kropotkin
# Processing Record 44 of Set 2 | santa maria
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | padang
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 3 | nouakchott
# Processing Record 2 of Set 3 | ambanja
# Processing Record 3 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 3 | havre-saint-pierre
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | da nang
# Processing Record 11 of Set 3 | pacific grove
# Processing Record 12 of Set 3 | beringovskiy
# Processing Record 13 of Set 3 | moree
# Processing Record 14 of Set 3 | bukama
# Processing Record 15 of Set 3 | kendari
# Processing Record 16 of Set 3 | hagere hiywet
# Processing Record 17 of Set 3 | hammerfest
# Processing Record 18 of Set 3 | xam nua
# Processing Record 19 of Set 3 | gorontalo
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | mayo
# Processing Record 22 of Set 3 | shieli
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | tuni
# Processing Record 29 of Set 3 | deputatskiy
# Processing Record 30 of Set 3 | atuona
# Processing Record 31 of Set 3 | pingshan
# Processing Record 32 of Set 3 | keti bandar
# Processing Record 33 of Set 3 | knysna
# Processing Record 34 of Set 3 | digby
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | cockburn town
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | portland
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | clyde river
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | anloga
# Processing Record 47 of Set 3 | bilma
# Processing Record 48 of Set 3 | comodoro rivadavia
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | naliya
# Processing Record 2 of Set 4 | hastings
# Processing Record 3 of Set 4 | requena
# Processing Record 4 of Set 4 | luanda
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | flinders
# Processing Record 7 of Set 4 | santander jimenez
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | suntar
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | saskatoon
# Processing Record 12 of Set 4 | manwath
# City not found. Skipping...
# Processing Record 13 of Set 4 | half moon bay
# Processing Record 14 of Set 4 | cururupu
# Processing Record 15 of Set 4 | acari
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | grindavik
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | krasnovishersk
# Processing Record 23 of Set 4 | sinegorye
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | diffa
# Processing Record 26 of Set 4 | aksay
# Processing Record 27 of Set 4 | cootamundra
# Processing Record 28 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 29 of Set 4 | gondanglegi
# Processing Record 30 of Set 4 | behshahr
# Processing Record 31 of Set 4 | lamar
# Processing Record 32 of Set 4 | cape town
# Processing Record 33 of Set 4 | boralday
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | beyneu
# Processing Record 36 of Set 4 | coffs harbour
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | puerto escondido
# Processing Record 39 of Set 4 | karratha
# Processing Record 40 of Set 4 | sao filipe
# Processing Record 41 of Set 4 | mtimbira
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 4 | baracoa
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | mandera
# Processing Record 48 of Set 4 | matara
# Processing Record 49 of Set 4 | yumen
# Processing Record 50 of Set 4 | hamilton
# Processing Record 1 of Set 5 | namatanai
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | tabas
# Processing Record 4 of Set 5 | viedma
# Processing Record 5 of Set 5 | norman wells
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | stornoway
# Processing Record 8 of Set 5 | kaitangata
# Processing Record 9 of Set 5 | camocim
# Processing Record 10 of Set 5 | berlevag
# Processing Record 11 of Set 5 | salinopolis
# Processing Record 12 of Set 5 | hilo
# Processing Record 13 of Set 5 | port blair
# Processing Record 14 of Set 5 | kuznechnoye
# Processing Record 15 of Set 5 | phan thiet
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | abalak
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | chunoyar
# Processing Record 21 of Set 5 | axixa do tocantins
# City not found. Skipping...
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | ipameri
# Processing Record 24 of Set 5 | panixtlahuaca
# City not found. Skipping...
# Processing Record 25 of Set 5 | tottori
# Processing Record 26 of Set 5 | namwala
# Processing Record 27 of Set 5 | magna
# Processing Record 28 of Set 5 | darhan
# Processing Record 29 of Set 5 | maragogi
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | sun valley
# Processing Record 32 of Set 5 | corinto
# Processing Record 33 of Set 5 | barnstaple
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | bouar
# Processing Record 36 of Set 5 | erzin
# Processing Record 37 of Set 5 | yerbogachen
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | sarai naurang
# Processing Record 40 of Set 5 | los llanos de aridane
# Processing Record 41 of Set 5 | iqaluit
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | pangai
# Processing Record 44 of Set 5 | abidjan
# Processing Record 45 of Set 5 | bereda
# Processing Record 46 of Set 5 | jizan
# Processing Record 47 of Set 5 | ust-kuyga
# Processing Record 48 of Set 5 | garden city
# Processing Record 49 of Set 5 | calama
# Processing Record 50 of Set 5 | ahipara
# Processing Record 1 of Set 6 | wajir
# Processing Record 2 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 3 of Set 6 | lagos
# Processing Record 4 of Set 6 | itarema
# Processing Record 5 of Set 6 | okakarara
# Processing Record 6 of Set 6 | santa marta
# Processing Record 7 of Set 6 | pemba
# Processing Record 8 of Set 6 | terenos
# Processing Record 9 of Set 6 | pisco
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | inyonga
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | kashi
# Processing Record 14 of Set 6 | omaha
# Processing Record 15 of Set 6 | rio grande
# Processing Record 16 of Set 6 | coihaique
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | misratah
# Processing Record 19 of Set 6 | chuy
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | anadyr
# Processing Record 22 of Set 6 | gamba
# Processing Record 23 of Set 6 | durham
# Processing Record 24 of Set 6 | roma
# Processing Record 25 of Set 6 | mecca
# Processing Record 26 of Set 6 | amurzet
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | saint-denis
# Processing Record 29 of Set 6 | ergani
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | pekan
# Processing Record 32 of Set 6 | taltal
# Processing Record 33 of Set 6 | camacupa
# Processing Record 34 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sioux lookout
# Processing Record 36 of Set 6 | kalaleh
# Processing Record 37 of Set 6 | sao felix do xingu
# Processing Record 38 of Set 6 | narvik
# Processing Record 39 of Set 6 | armidale
# Processing Record 40 of Set 6 | barrow
# Processing Record 41 of Set 6 | dordrecht
# Processing Record 42 of Set 6 | ampanihy
# Processing Record 43 of Set 6 | kankaanpaa
# Processing Record 44 of Set 6 | dongsheng
# Processing Record 45 of Set 6 | fort wellington
# Processing Record 46 of Set 6 | usinsk
# Processing Record 47 of Set 6 | starobesheve
# Processing Record 48 of Set 6 | byron bay
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | martapura
# Processing Record 1 of Set 7 | dekar
# Processing Record 2 of Set 7 | odweyne
# Processing Record 3 of Set 7 | balkhash
# Processing Record 4 of Set 7 | alta floresta
# Processing Record 5 of Set 7 | nome
# Processing Record 6 of Set 7 | asau
# Processing Record 7 of Set 7 | saint anthony
# Processing Record 8 of Set 7 | fereydun kenar
# Processing Record 9 of Set 7 | great yarmouth
# Processing Record 10 of Set 7 | jinchang
# Processing Record 11 of Set 7 | kastamonu
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 7 | skibbereen
# Processing Record 14 of Set 7 | rawson
# Processing Record 15 of Set 7 | durban
# Processing Record 16 of Set 7 | sopelana
# Processing Record 17 of Set 7 | agadez
# Processing Record 18 of Set 7 | talas
# Processing Record 19 of Set 7 | haysville
# Processing Record 20 of Set 7 | port augusta
# Processing Record 21 of Set 7 | myre
# Processing Record 22 of Set 7 | merauke
# Processing Record 23 of Set 7 | maputo
# Processing Record 24 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 7 | leshukonskoye
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 28 of Set 7 | haines junction
# Processing Record 29 of Set 7 | imbituba
# Processing Record 30 of Set 7 | balkanabat
# Processing Record 31 of Set 7 | nemuro
# Processing Record 32 of Set 7 | ibipora
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | benghazi
# Processing Record 35 of Set 7 | pacifica
# Processing Record 36 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 7 | nouadhibou
# Processing Record 38 of Set 7 | dunedin
# Processing Record 39 of Set 7 | kurchum
# Processing Record 40 of Set 7 | cotonou
# Processing Record 41 of Set 7 | ishikawa
# Processing Record 42 of Set 7 | nuevo progreso
# Processing Record 43 of Set 7 | gorele
# Processing Record 44 of Set 7 | torbay
# Processing Record 45 of Set 7 | port elizabeth
# Processing Record 46 of Set 7 | shelburne
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | vila do maio
# Processing Record 49 of Set 7 | mto wa mbu
# Processing Record 50 of Set 7 | cap malheureux
# Processing Record 1 of Set 8 | umm kaddadah
# Processing Record 2 of Set 8 | puerto del rosario
# Processing Record 3 of Set 8 | helong
# Processing Record 4 of Set 8 | visnes
# Processing Record 5 of Set 8 | madimba
# Processing Record 6 of Set 8 | ekhabi
# Processing Record 7 of Set 8 | san borja
# Processing Record 8 of Set 8 | erattupetta
# Processing Record 9 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 8 | rosario
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | bihariganj
# Processing Record 13 of Set 8 | hede
# Processing Record 14 of Set 8 | chilca
# Processing Record 15 of Set 8 | lasa
# Processing Record 16 of Set 8 | atlantic city
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | the valley
# Processing Record 19 of Set 8 | chippewa falls
# Processing Record 20 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 8 | shache
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | guamal
# Processing Record 24 of Set 8 | kijang
# Processing Record 25 of Set 8 | vokhtoga
# Processing Record 26 of Set 8 | churapcha
# Processing Record 27 of Set 8 | dingle
# Processing Record 28 of Set 8 | am timan
# Processing Record 29 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 8 | san-pedro
# Processing Record 31 of Set 8 | alexandria
# Processing Record 32 of Set 8 | wilmington
# Processing Record 33 of Set 8 | xacmaz
# Processing Record 34 of Set 8 | shakiso
# Processing Record 35 of Set 8 | matadi
# Processing Record 36 of Set 8 | sydney
# Processing Record 37 of Set 8 | maxixe
# Processing Record 38 of Set 8 | hofn
# Processing Record 39 of Set 8 | belaya gora
# Processing Record 40 of Set 8 | jiwani
# Processing Record 41 of Set 8 | mahajanga
# Processing Record 42 of Set 8 | horsham
# Processing Record 43 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 8 | naivasha
# Processing Record 45 of Set 8 | gararu
# Processing Record 46 of Set 8 | verdun
# Processing Record 47 of Set 8 | axim
# Processing Record 48 of Set 8 | samarai
# Processing Record 49 of Set 8 | airai
# Processing Record 50 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 9 | conceicao do araguaia
# Processing Record 2 of Set 9 | winona
# Processing Record 3 of Set 9 | castro
# Processing Record 4 of Set 9 | nanortalik
# Processing Record 5 of Set 9 | zlobin
# Processing Record 6 of Set 9 | nalut
# Processing Record 7 of Set 9 | fort saint james
# Processing Record 8 of Set 9 | trapani
# Processing Record 9 of Set 9 | balikpapan
# Processing Record 10 of Set 9 | coxim
# Processing Record 11 of Set 9 | nikel
# Processing Record 12 of Set 9 | autlan
# City not found. Skipping...
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | arlit
# Processing Record 15 of Set 9 | tezu
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | la rioja
# Processing Record 18 of Set 9 | charcas
# Processing Record 19 of Set 9 | barra patuca
# Processing Record 20 of Set 9 | matiri
# Processing Record 21 of Set 9 | thinadhoo
# Processing Record 22 of Set 9 | tual
# Processing Record 23 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | san rafael
# Processing Record 26 of Set 9 | tasiilaq
# Processing Record 27 of Set 9 | pouembout
# Processing Record 28 of Set 9 | lensk
# Processing Record 29 of Set 9 | motygino
# Processing Record 30 of Set 9 | atar
# Processing Record 31 of Set 9 | cedar city
# Processing Record 32 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 9 | skelleftea
# Processing Record 34 of Set 9 | alenquer
# Processing Record 35 of Set 9 | korla
# Processing Record 36 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 9 | pokrovskoye
# Processing Record 38 of Set 9 | dalvik
# Processing Record 39 of Set 9 | bay roberts
# Processing Record 40 of Set 9 | mahibadhoo
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 43 of Set 9 | nara
# Processing Record 44 of Set 9 | tateyama
# Processing Record 45 of Set 9 | qostanay
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | camalu
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | monoharpur
# Processing Record 50 of Set 9 | revda
# Processing Record 1 of Set 10 | mirnyy
# Processing Record 2 of Set 10 | schattdorf
# Processing Record 3 of Set 10 | huanan
# Processing Record 4 of Set 10 | neijiang
# Processing Record 5 of Set 10 | kalispell
# Processing Record 6 of Set 10 | zhangye
# Processing Record 7 of Set 10 | olga
# Processing Record 8 of Set 10 | santa paula
# Processing Record 9 of Set 10 | los zacatones
# Processing Record 10 of Set 10 | maumere
# Processing Record 11 of Set 10 | guarapuava
# Processing Record 12 of Set 10 | goure
# Processing Record 13 of Set 10 | vestmanna
# Processing Record 14 of Set 10 | valenii de munte
# Processing Record 15 of Set 10 | coahuayana
# Processing Record 16 of Set 10 | hirara
# Processing Record 17 of Set 10 | buzuluk
# Processing Record 18 of Set 10 | aksarka
# Processing Record 19 of Set 10 | chara
# Processing Record 20 of Set 10 | caohe
# Processing Record 21 of Set 10 | beloha
# Processing Record 22 of Set 10 | ulaangom
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | tanabe
# Processing Record 25 of Set 10 | pamplona
# Processing Record 26 of Set 10 | mehran
# Processing Record 27 of Set 10 | tilichiki
# Processing Record 28 of Set 10 | keetmanshoop
# Processing Record 29 of Set 10 | lata
# Processing Record 30 of Set 10 | liberal
# Processing Record 31 of Set 10 | high level
# Processing Record 32 of Set 10 | eskilstuna
# Processing Record 33 of Set 10 | salalah
# Processing Record 34 of Set 10 | shalyhyne
# Processing Record 35 of Set 10 | wiehl
# Processing Record 36 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 10 | chaltyr
# Processing Record 38 of Set 10 | mazatlan
# Processing Record 39 of Set 10 | cariamanga
# Processing Record 40 of Set 10 | catamarca
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | zarubino
# Processing Record 43 of Set 10 | hualmay
# Processing Record 44 of Set 10 | aksehir
# Processing Record 45 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 10 | garowe
# Processing Record 48 of Set 10 | morehead
# Processing Record 49 of Set 10 | antsohihy
# Processing Record 50 of Set 10 | kavaratti
# Processing Record 1 of Set 11 | wheeling
# Processing Record 2 of Set 11 | bignona
# Processing Record 3 of Set 11 | aykhal
# Processing Record 4 of Set 11 | radzyn podlaski
# Processing Record 5 of Set 11 | palkaka
# City not found. Skipping...
# Processing Record 6 of Set 11 | huilong
# Processing Record 7 of Set 11 | tessalit
# Processing Record 8 of Set 11 | hervey bay
# Processing Record 9 of Set 11 | novovasylivka
# Processing Record 10 of Set 11 | fairbanks
# Processing Record 11 of Set 11 | okha
# Processing Record 12 of Set 11 | san pedro
# Processing Record 13 of Set 11 | komsomolskiy
# Processing Record 14 of Set 11 | vestmannaeyjar
# Processing Record 15 of Set 11 | northampton
# Processing Record 16 of Set 11 | saint-georges
# Processing Record 17 of Set 11 | isabela
# Processing Record 18 of Set 11 | tehri
# Processing Record 19 of Set 11 | fortuna
# Processing Record 20 of Set 11 | udachnyy
# Processing Record 21 of Set 11 | shunyi
# Processing Record 22 of Set 11 | conde
# Processing Record 23 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 11 | camacha
# Processing Record 25 of Set 11 | kalianget
# Processing Record 26 of Set 11 | jalu
# Processing Record 27 of Set 11 | buturlinovka
# Processing Record 28 of Set 11 | coalinga
# Processing Record 29 of Set 11 | bara
# Processing Record 30 of Set 11 | dalby
# Processing Record 31 of Set 11 | san francisco
# Processing Record 32 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 11 | chokurdakh
# Processing Record 34 of Set 11 | haimen
# Processing Record 35 of Set 11 | seoul
# Processing Record 36 of Set 11 | ancud
# Processing Record 37 of Set 11 | tahta
# Processing Record 38 of Set 11 | effingham
# Processing Record 39 of Set 11 | aswan
# Processing Record 40 of Set 11 | boyolangu
# Processing Record 41 of Set 11 | macaubas
# Processing Record 42 of Set 11 | wageningen
# Processing Record 43 of Set 11 | mali
# Processing Record 44 of Set 11 | rundu
# Processing Record 45 of Set 11 | mumford
# Processing Record 46 of Set 11 | resistencia
# Processing Record 47 of Set 11 | sharjah
# Processing Record 48 of Set 11 | port lincoln
# Processing Record 49 of Set 11 | marawi
# Processing Record 50 of Set 11 | yulara
# Processing Record 1 of Set 12 | gold coast
# Processing Record 2 of Set 12 | arkhipo-osipovka
# Processing Record 3 of Set 12 | kudahuvadhoo
# Processing Record 4 of Set 12 | tiznit
# Processing Record 5 of Set 12 | gorkovskoye
# City not found. Skipping...
# Processing Record 6 of Set 12 | alice springs
# Processing Record 7 of Set 12 | moose factory
# Processing Record 8 of Set 12 | ola
# Processing Record 9 of Set 12 | hermosillo
# Processing Record 10 of Set 12 | manadhoo
# Processing Record 11 of Set 12 | hambantota
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | buenaventura
# Processing Record 14 of Set 12 | westport
# Processing Record 15 of Set 12 | northam
# Processing Record 16 of Set 12 | belmonte
# Processing Record 17 of Set 12 | losinyy
# Processing Record 18 of Set 12 | arzgir
# Processing Record 19 of Set 12 | mandalgovi
# Processing Record 20 of Set 12 | astoria
# Processing Record 21 of Set 12 | ushtobe
# Processing Record 22 of Set 12 | maryborough
# Processing Record 23 of Set 12 | that phanom
# Processing Record 24 of Set 12 | mafeteng
# Processing Record 25 of Set 12 | barcelona
# Processing Record 26 of Set 12 | kampene
# Processing Record 27 of Set 12 | holland
# Processing Record 28 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 12 | varca
# Processing Record 30 of Set 12 | bardiyah
# Processing Record 31 of Set 12 | mangai
# Processing Record 32 of Set 12 | alcamo
# Processing Record 33 of Set 12 | canico
# Processing Record 34 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 12 | aviles
# Processing Record 36 of Set 12 | narsaq
# Processing Record 37 of Set 12 | roald
# Processing Record 38 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 12 | caranavi
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | charters towers
# Processing Record 43 of Set 12 | riberalta
# Processing Record 44 of Set 12 | ruidoso
# Processing Record 45 of Set 12 | eyrarbakki
# Processing Record 46 of Set 12 | gloversville
# Processing Record 47 of Set 12 | coquimbo
# Processing Record 48 of Set 12 | urengoy
# Processing Record 49 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 12 | french harbor
# Processing Record 1 of Set 13 | novobiryusinskiy
# Processing Record 2 of Set 13 | grand junction
# Processing Record 3 of Set 13 | camana
# Processing Record 4 of Set 13 | east islip
# Processing Record 5 of Set 13 | burns lake
# Processing Record 6 of Set 13 | katherine
# Processing Record 7 of Set 13 | matagami
# Processing Record 8 of Set 13 | tura
# Processing Record 9 of Set 13 | chingola
# Processing Record 10 of Set 13 | gushikawa
# Processing Record 11 of Set 13 | fuyu
# Processing Record 12 of Set 13 | price
# Processing Record 13 of Set 13 | xichang
# Processing Record 14 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 13 | quime
# Processing Record 16 of Set 13 | kulhudhuffushi
# Processing Record 17 of Set 13 | ust-kan
# Processing Record 18 of Set 13 | opuwo
# Processing Record 19 of Set 13 | brentwood
# Processing Record 20 of Set 13 | newport
# Processing Record 21 of Set 13 | sechura
# Processing Record 22 of Set 13 | caravelas
# Processing Record 23 of Set 13 | ialibu
# Processing Record 24 of Set 13 | rafraf
# Processing Record 25 of Set 13 | florianopolis
# Processing Record 26 of Set 13 | brigantine
# Processing Record 27 of Set 13 | sand springs
# Processing Record 28 of Set 13 | karatuzskoye
# Processing Record 29 of Set 13 | svendborg
# Processing Record 30 of Set 13 | ugoofaaru
# Processing Record 31 of Set 13 | amahai
# Processing Record 32 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 13 | paraiso
# Processing Record 34 of Set 13 | canmore
# Processing Record 35 of Set 13 | auki
# Processing Record 36 of Set 13 | san quintin
# Processing Record 37 of Set 13 | maningrida
# Processing Record 38 of Set 13 | veraval
# Processing Record 39 of Set 13 | xuddur
# Processing Record 40 of Set 13 | ucluelet
# Processing Record 41 of Set 13 | dalbandin
# Processing Record 42 of Set 13 | mpika
# Processing Record 43 of Set 13 | boulsa
# Processing Record 44 of Set 13 | porto novo
# Processing Record 45 of Set 13 | salamiyah
# Processing Record 46 of Set 13 | pokhara
# Processing Record 47 of Set 13 | guarapari
# Processing Record 48 of Set 13 | izmaylovo
# Processing Record 49 of Set 13 | wajima
# Processing Record 50 of Set 13 | hedaru
# Processing Record 1 of Set 14 | sisimiut
# Processing Record 2 of Set 14 | qaqortoq
# Processing Record 3 of Set 14 | bahir dar
# Processing Record 4 of Set 14 | ailigandi
# Processing Record 5 of Set 14 | neuquen
# Processing Record 6 of Set 14 | esmeralda
# Processing Record 7 of Set 14 | eshowe
# Processing Record 8 of Set 14 | lanzhou
# Processing Record 9 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 14 | nizhnevartovsk
# Processing Record 11 of Set 14 | thohoyandou
# Processing Record 12 of Set 14 | atambua
# Processing Record 13 of Set 14 | lashio
# Processing Record 14 of Set 14 | batemans bay
# Processing Record 15 of Set 14 | raiganj
# Processing Record 16 of Set 14 | henties bay
# Processing Record 17 of Set 14 | arucas
# Processing Record 18 of Set 14 | san juan
# Processing Record 19 of Set 14 | jaguaruna
# Processing Record 20 of Set 14 | yarmouth
# Processing Record 21 of Set 14 | izumo
# Processing Record 22 of Set 14 | husavik
# Processing Record 23 of Set 14 | kajaani
# Processing Record 24 of Set 14 | watertown
# Processing Record 25 of Set 14 | houma
# Processing Record 26 of Set 14 | rocha
# Processing Record 27 of Set 14 | general pico
# Processing Record 28 of Set 14 | krasnoselkup
# Processing Record 29 of Set 14 | tripoli
# Processing Record 30 of Set 14 | valer
# Processing Record 31 of Set 14 | yunyang
# Processing Record 32 of Set 14 | mama
# Processing Record 33 of Set 14 | zheleznodorozhnyy
# Processing Record 34 of Set 14 | pringsewu
# Processing Record 35 of Set 14 | leningradskiy
# Processing Record 36 of Set 14 | brae
# Processing Record 37 of Set 14 | lesnica
# Processing Record 38 of Set 14 | armeria
# Processing Record 39 of Set 14 | shibetsu
# Processing Record 40 of Set 14 | biak
# Processing Record 41 of Set 14 | baykit
# Processing Record 42 of Set 14 | zhigansk
# Processing Record 43 of Set 14 | makakilo city
# Processing Record 44 of Set 14 | kenora
# Processing Record 45 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 46 of Set 14 | north platte
# Processing Record 47 of Set 14 | gravdal
# Processing Record 48 of Set 14 | monrovia
# Processing Record 49 of Set 14 | aksu
# Processing Record 50 of Set 14 | aginskoye
# Processing Record 1 of Set 15 | bereslavka
# Processing Record 2 of Set 15 | saint-francois
# Processing Record 3 of Set 15 | worthing
# Processing Record 4 of Set 15 | rincon
# Processing Record 5 of Set 15 | colorado springs
# Processing Record 6 of Set 15 | awbari
# Processing Record 7 of Set 15 | oistins
# Processing Record 8 of Set 15 | fryazino
# Processing Record 9 of Set 15 | mayumba
# Processing Record 10 of Set 15 | ipixuna
# Processing Record 11 of Set 15 | sergeyevka
# Processing Record 12 of Set 15 | heihe
# Processing Record 13 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 15 | whyalla
# Processing Record 15 of Set 15 | kandrian
# Processing Record 16 of Set 15 | takoradi
# Processing Record 17 of Set 15 | grand gaube
# Processing Record 18 of Set 15 | sinnamary
# Processing Record 19 of Set 15 | cortez
# Processing Record 20 of Set 15 | barnala
# Processing Record 21 of Set 15 | qunduz
# Processing Record 22 of Set 15 | charyshskoye
# Processing Record 23 of Set 15 | loikaw
# Processing Record 24 of Set 15 | bata
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | nguru
# Processing Record 27 of Set 15 | antalaha
# Processing Record 28 of Set 15 | lere
# Processing Record 29 of Set 15 | redditch
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | jember
# Processing Record 32 of Set 15 | adrar
# Processing Record 33 of Set 15 | paragominas
# Processing Record 34 of Set 15 | karacabey
# Processing Record 35 of Set 15 | huinan
# Processing Record 36 of Set 15 | huarmey
# Processing Record 37 of Set 15 | jiuquan
# Processing Record 38 of Set 15 | soyo
# Processing Record 39 of Set 15 | vila
# Processing Record 40 of Set 15 | xuanzhou
# Processing Record 41 of Set 15 | kenai
# Processing Record 42 of Set 15 | calabozo
# Processing Record 43 of Set 15 | pundaguitan
# Processing Record 44 of Set 15 | bafia
# Processing Record 45 of Set 15 | ketchikan
# Processing Record 46 of Set 15 | osinki
# Processing Record 47 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 15 | bowen
# Processing Record 49 of Set 15 | keskin
# Processing Record 50 of Set 15 | barcelos
# Processing Record 1 of Set 16 | lodwar
# Processing Record 2 of Set 16 | kloulklubed
# Processing Record 3 of Set 16 | chicama
# Processing Record 4 of Set 16 | lexington
# Processing Record 5 of Set 16 | kokubu
# Processing Record 6 of Set 16 | san ramon
# Processing Record 7 of Set 16 | crixas
# Processing Record 8 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 16 | goundam
# Processing Record 10 of Set 16 | nokaneng
# Processing Record 11 of Set 16 | granville
# Processing Record 12 of Set 16 | temba
# Processing Record 13 of Set 16 | pouebo
# Processing Record 14 of Set 16 | rantepao
# Processing Record 15 of Set 16 | taoudenni
# Processing Record 16 of Set 16 | teahupoo
# Processing Record 17 of Set 16 | pafos
# Processing Record 18 of Set 16 | shima
# Processing Record 19 of Set 16 | bolu
# Processing Record 20 of Set 16 | barillas
# Processing Record 21 of Set 16 | springfield
# Processing Record 22 of Set 16 | joshimath
# Processing Record 23 of Set 16 | jiamusi
# Processing Record 24 of Set 16 | jalingo
# Processing Record 25 of Set 16 | fort thomas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 721

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0        Katangli   51.7102   143.2326      4.59        91         100
# 1        Denpasar   -8.6500   115.2167     78.46        88          20
# 2    Punta Arenas  -53.1500   -70.9167     55.51        44           0
# 3         Ushuaia  -54.8000   -68.3000     49.62        81          75
# 4        Khatanga   71.9667   102.5000     -7.15       100          97
# 5        Thompson   55.7435   -97.8558     -9.24        77          75
# 6  Saint-Philippe  -21.3585    55.7679     78.39        81          67
# 7           Vaini  -21.2000  -175.2000     71.76        94          20
# 8         Rikitea  -23.1203  -134.9692     76.08        79         100
# 9       Mamlyutka   54.9375    68.5394     10.13        96          93
#
#    Wind Speed Country Weather Description
# 0       16.55      RU     overcast clouds
# 1        1.14      ID          few clouds
# 2       24.16      CL           clear sky
# 3       25.32      AR          light rain
# 4        5.21      RU     overcast clouds
# 5        9.22      CA       broken clouds
# 6       14.58      RE          light rain
# 7        3.44      TO          few clouds
# 8       11.36      PF     overcast clouds
# 9        6.62      KZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Latitude', 'Longitude', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ['City', 'Country', 'Latitude', 'Longitude', 'Max Temp', 'Humidity',  'Cloudiness', 'Wind Speed', 'Weather Description']


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_columns]


# Display sample data
city_data_df.tail(10)
# Out:
#               City Country  Latitude  Longitude  Max Temp  Humidity  \
# 711       Teahupoo      PF  -17.8333  -149.2667     75.16        78
# 712         Paphos      CY   34.7667    32.4167     62.38        88
# 713          Shima      CN   24.4478   117.8111     50.02        72
# 714  Bolu Province      TR   40.6667    31.5833     48.94        80
# 715       Barillas      GT   15.8036   -91.3158     73.11        54
# 716    Springfield      US   37.2153   -93.2982     28.22        66
# 717      Joshīmath      IN   30.5667    79.5667     49.12        22
# 718        Jiamusi      CN   46.8333   130.3500     -7.49        87
# 719        Jalingo      NG    8.8833    11.3667     81.25        17
# 720    Fort Thomas      US   39.0751   -84.4472     35.02        66
#
#      Cloudiness  Wind Speed Weather Description
# 711          90        6.62          light rain
# 712          88        4.61     overcast clouds
# 713          42        6.29    scattered clouds
# 714          30        4.65    scattered clouds
# 715          77        4.90       broken clouds
# 716         100       11.50     overcast clouds
# 717           0        7.40           clear sky
# 718          82        3.96       broken clouds
# 719          90        4.72     overcast clouds
# 720         100       13.80     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Latitude               float64
# Longitude              float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name

output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
